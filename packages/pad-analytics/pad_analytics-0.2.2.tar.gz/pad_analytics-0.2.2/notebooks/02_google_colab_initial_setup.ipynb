# %% [markdown]
# # Introduction
#
# This notebook will guide you through the setup and workflow necessary to integrate Google Colab with Google Drive and work with GitHub repositories. By following these steps, you'll be able to clone, manage, and update a repository inside your Google Drive for seamless collaboration and development.

# %% [markdown]
# ### Step 1: Mount Google Drive in Colab
# To start, you'll need to connect Google Colab to your Google Drive. This will allow you to access, store, and retrieve files directly from your Drive.
#
# Run the code below to mount your Google Drive. After running the code, a prompt will appear asking for authorization—please follow the steps to grant access.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Step 2: Create the `pad-ml` Folder
# After successfully mounting your Google Drive, the next step is to create a folder where all your files and resources will be organized.
#
# Use the following command to create a folder named `pad-ml` inside your Google Drive under **My Drive**. This folder will serve as a workspace for storing files, cloning GitHub repositories, and saving your work directly from Colab.

# %%
# !mkdir /content/drive/My\ Drive/pad-ml

# %% [markdown]
# The command will create a folder named `pad-ml` in the **My Drive** section of your Google Drive.
#
# ![image.png](data:image/png;base64,...)
#
# You can now use the `pad-ml` folder to organize your project files, clone GitHub repositories, and save any work you do in Google Colab.

# %% [markdown]
# ### Step 3: Navigate to the `pad-ml` Folder
# Before we clone the GitHub repository, let's ensure we're in the correct working directory. You need to navigate into the `pad-ml` folder where the repository will be cloned.

# %%
# %cd /content/drive/My\ Drive/pad-ml/

# %% [markdown]
#  To verify your current working directory, run the following command `!pwd`.
#
#    This will show you the directory you're currently in. Ensure that it displays the `pad-ml` folder.

# %%
# !pwd

# %% [markdown]
# ### Step 4: Clone the GitHub Repository into the `pad-ml` Folder
#    Now that you're inside the `pad-ml` folder, it's time to clone the GitHub repository containing the PADs ML workflow.
#
#    Run the following command to clone the repository directly into your `pad-ml` folder.

# %%
# !git clone https://github.com/PaperAnalyticalDeviceND/pad-analytics.git

# %% [markdown]
# *Note: The repository will be placed inside the `pad-ml` folder.*
#
# ![image.png](data:image/png;base64,...)
#
#    After cloning, you can confirm that the repository is successfully copied by listing the contents of the folder using the following command `!ls`.
#
#
#    This will display all files and directories within your `pad-ml` folder.

# %%
# !ls .
# Out:
# pad-analytics

# %% [markdown]
#    Now that the repository is cloned, you can access and edit your Jupyter notebooks directly from Google Colab. This will allow you to interact with the files in the cloned repository and execute code cells as needed.

# %%
# %cd pad-analytics
# !ls

# %% [markdown]
#    ### Step 5: Keep the GitHub Repository Updated
#    From time to time, the repository might receive updates. To ensure you have the latest version of the project, you can pull the latest changes using the following command:
#
#    ```python
#    !git pull
#    ```
#
#    This command will fetch and merge any new commits from the original GitHub repository into your local copy in Colab.

# %%
# !git pull
