# %% [markdown]
# # DandeLiion API - PyBaMM comparison

# %%
import dandeliion.client as dandeliion
import numpy as np
import matplotlib.pyplot as plt
import pybamm
from pybamm import Experiment

# The following lines enable logging output in this notebook
import sys
import logging
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# %%
dandeliion.__version__
# Out:
# '1.0.0rc2'

# %% [markdown]
# ### Authentication
# Define the simulator object by providing the API URL and API token:

# %%
api_url = "https://api.dandeliion.com/v1"
api_key = "f1543b9ff2001d04bd2c002d9375c8a28ad0bcac9914ce5d8f0e0b98ef4404cf"
simulator = dandeliion.Simulator(api_url, api_key)

# %% [markdown]
# ### Battery parameters
# Can be a valid BPX file name/path or already read-in valid BPX as a `dict` or `BPX` object itself:

# %%
# params = '2025-04-10-parameters_Dandeliion_example.json'
params = 'AE_gen1_BPX.json'

# %% [markdown]
# ### Experiment
# PyBaMM `Experiment` object, for example:

# %%
experiment = Experiment(
  [
      "Discharge at C/2 for 10 hours or until 2.5 V"  # Discharging at 1C crashes PyBaMM
  ],
  period = "10 s",
)

# %% [markdown]
# ### Additional model/backend-specific parameters
# Define a dictionary of extra parameters outside the BPX standard, such as mesh, initial state of charge or voltage, etc.:

# %%
extra_params = {}

is_isothermal = True

# Number of mesh points in PyBaMM format (default is 16 mesh points everywhere):
extra_params['Mesh'] = {"x_n": 32, "x_s": 16, "x_p": 32, "r_n": 32, "r_p": 32}

# Initial state of charge (default is 1):
extra_params['Initial SOC'] = 1.0

# %% [markdown]
# ### Start the simulation in the cloud

# %%
solution = dandeliion.solve(
    simulator=simulator,
    params=params,
    experiment=experiment,      # optional (1C discharge for 1 hour or until the `Lower voltage cut-off [V]` from BPX will be used by default)
    extra_params=extra_params,  # optional (initial conditions from the BPX, fully charged state, and single cell Newman model with constant temperature will be used by default)
    is_blocking=True            # optional (`True` by default)
)

print("Solution status:", solution.status)
# Out:
# /home/ivan/workspace/dandeliion-client/.venv-pip/lib/python3.10/site-packages/pydantic/_internal/_decorators_v1.py:171: UserWarning: The minimum voltage computed from the STO limits (2.4988861558265327 V) is less than the lower voltage cut-off (2.5 V) with the absolute tolerance v_tol = 0.001 V
#   model_dict_new = validator(model_dict)
# INFO:dandeliion.client.simulator:[running] |
# INFO:dandeliion.client.simulator:[success] | [2025-05-09 17:53:46.007] [info] Total time: 3.904 s
# Solution status: success

# %% [markdown]
# ### Start PyBaMM simulation with the same parameters

# %%
print(f"\nPyBaMM {pybamm.__version__} simulation...\n")

pybamm_params = pybamm.ParameterValues.create_from_bpx(params)

if is_isothermal:
    model = pybamm.lithium_ion.DFN()

else:
    pybamm_params.update(
        {
            "Total heat transfer coefficient [W.m-2.K-1]": 0.0,
        },
        check_already_exists=False,
    )

    model_opts = {"thermal": "lumped", "cell geometry": "arbitrary"}

    model = pybamm.lithium_ion.DFN(options=model_opts)

# Sim object
sim = pybamm.Simulation(
    model,
    parameter_values=pybamm_params,
    experiment=experiment,
    var_pts=extra_params['Mesh'],
)

sol = sim.solve()

t_eval = np.arange(0, 10 * 3600, 10)

# PyBaMM outputs
t = sol["Time [s]"](t=t_eval)
I = sol["Current [A]"](t=t_eval)
V = sol["Voltage [V]"](t=t_eval)
T = sol["Volume-averaged cell temperature [K]"](t=t_eval)
x = sol["x [m]"](t=t_eval)
ce = sol["Electrolyte concentration [mol.m-3]"](t=t_eval)
# Out:
# PyBaMM 25.1.1 simulation...
# /home/ivan/workspace/dandeliion-client/.venv-pip/lib/python3.10/site-packages/pybamm/parameters/parameter_values.py:163: UserWarning: 'Open-circuit voltage at 0% SOC [V]' not found in BPX file. Using 'Lower voltage cut-off [V]'.
#   return ParameterValues._create_from_bpx(bpx, target_soc)
# /home/ivan/workspace/dandeliion-client/.venv-pip/lib/python3.10/site-packages/pybamm/parameters/parameter_values.py:163: UserWarning: 'Open-circuit voltage at 100% SOC [V]' not found in BPX file. Using 'Upper voltage cut-off [V]'.
#   return ParameterValues._create_from_bpx(bpx, target_soc)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 33
#      30 t_eval = np.arange(0, 10 * 3600, 10)
#      32 # PyBaMM outputs
# ---> 33 t = sol["Time [s]"](t=t_eval)
#      34 I = sol["Current [A]"](t=t_eval)
#      35 V = sol["Voltage [V]"](t=t_eval)
#
# File ~/workspace/dandeliion-client/.venv-pip/lib/python3.10/site-packages/pybamm/solvers/processed_variable.py:257, in ProcessedVariable.__call__(self, t, x, r, y, z, R, fill_value)
#     255     entries_for_interp, coords = self._interp_setup(entries, t_observe)
#     256 else:
# --> 257     self.initialise()
#     258     entries_for_interp, coords = (
#     259         self._entries_for_interp_raw,
#     260         self._coords_raw,
#     261     )
#     263 if self.time_integral is None:
#
# File ~/workspace/dandeliion-client/.venv-pip/lib/python3.10/site-packages/pybamm/solvers/processed_variable.py:85, in ProcessedVariable.initialise(self)
#      82 if self.entries_raw_initialized:
#      83     return
# ---> 85 entries = self.observe_raw()
#      87 t = self.t_pts
#      88 entries_for_interp, coords = self._interp_setup(entries, t)
#
# File ~/workspace/dandeliion-client/.venv-pip/lib/python3.10/site-packages/pybamm/solvers/processed_variable.py:116, in ProcessedVariable.observe_raw(self)
#     112 """
#     113 Evaluate the base variable at the given time points and y values.
#     114 """
#     115 t = self.t_pts
# --> 116 return self._observe_postfix(self._observe_raw_cpp(), t)
#
# File ~/workspace/dandeliion-client/.venv-pip/lib/python3.10/site-packages/pybamm/solvers/processed_variable.py:178, in ProcessedVariable._observe_raw_cpp(self)
#     173 ts, ys, _, funcs, inputs, is_f_contiguous = self._setup_cpp_inputs(
#     174     t, full_range=True
#     175 )
#     176 shapes = self._shape(self.t_pts)
# --> 178 return idaklu.observe(ts, ys, inputs, funcs, is_f_contiguous, shapes)
#
# RuntimeError: .../casadi/core/serializing_stream.cpp:381: Assertion "load_version==v" failed:
# DeSerialization of SXFunction failed. Object written in version 2 but can only read in version 1.

# %%
t_eval = np.arange(0, 10 * 3600, 10)

# PyBaMM outputs
print(sol["Time [s]"](t=t_eval))


solution.status
# Out:
# <pybamm.solvers.processed_variable.ProcessedVariable0D object at 0x7fdd14ecdde0>
# 'success'

# %% [markdown]
# ### Accessing the log file

# %%
print(solution.log)
# Out:
# [2025-05-09 17:13:09.249] [info] Starting dandeliion-models v0.1.1...
# [2025-05-09 17:13:09.249] [info] Parsing input JSON file parameters.json...
# [2025-05-09 17:13:09.249] [info] Input JSON file parsing time: 0.091 ms
# [2025-05-09 17:13:09.249] [info] Initialising simulation parameters...
# [2025-05-09 17:13:09.249] [info] Title: Parameterisation of our example cell
# [2025-05-09 17:13:09.249] [info] Model: DFN
# [2025-05-09 17:13:09.256] [info] Thermal model: Isothermal
# [2025-05-09 17:13:09.256] [info] Found DandeLiion Experiment...
# [2025-05-09 17:13:09.256] [info] Number of instructions to parse: 1
# [2025-05-09 17:13:09.256] [info] Solver mode: Fast (default)
# [2025-05-09 17:13:09.256] [info] Simulation parameters initialisation time: 6.705 ms
# [2025-05-09 17:13:09.256] [info] Starting the simulation...
# [2025-05-09 17:13:09.256] [info] Computational mesh: 31x31 + 15 + 31x31 finite volumes
# [2025-05-09 17:13:09.256] [info] Total number of equations: 2204
# [2025-05-09 17:13:09.256] [info] Updating inconsistent initial conditions...
# [2025-05-09 17:13:09.271] [info] Initial conditions settled in: 15.091 ms
# [2025-05-09 17:13:09.271] [info] Instruction #1 of 1: Discharge at 1 [C] until 2.5 [V]...
# [2025-05-09 17:13:15.467] [warning] DAE solver diverged at time t = 10012.737004947663
# [2025-05-09 17:13:15.467] [info] Simulation time: 6.211 s
# [2025-05-09 17:13:15.467] [info] Writing the output to output.json...
# [2025-05-09 17:13:15.493] [info] Output JSON file writing time: 25.931 ms
# [2025-05-09 17:13:15.497] [info] Total time: 6.248 s

# %% [markdown]
# ### Results
# Print all available keys in the solution object.
# Here method `keys()` is used to get all available keys in the solution object.

# %%
for key in sorted(solution.keys()):
    print(key)
# Out:
# Current [A]
# Electrolyte concentration [mol.m-3]
# Electrolyte potential [V]
# Electrolyte x-coordinate [m]
# Temperature [K]
# Time [s]
# Voltage [V]
# X-averaged negative electrode exchange current density [A.m-2]
# X-averaged negative electrode potential [V]
# X-averaged negative electrode surface concentration [mol.m-3]
# X-averaged positive electrode exchange current density [A.m-2]
# X-averaged positive electrode potential [V]
# X-averaged positive electrode surface concentration [mol.m-3]

# %%
def last_non_nan(arr):
    """
    A helper function to get the last non-NaN element in an array and its index.
    """
    for idx, element in enumerate(arr[::-1]):
        if not np.isnan(element):
            return element, len(arr) - 1 - idx
    return None, None  # Return None, None if all elements are NaN

t_last, i_last = last_non_nan(t)

# Print the final values of time, voltage, and temperature
print(f"Final PyBaMM | DandeLiion time [s]: {t_last} | {solution['Time [s]'][-1]}")
print(f"Final PyBaMM | DandeLiion voltage [V]: {V[i_last]} | {solution['Voltage [V]'][-1]}")
print(f"Final PyBaMM | DandeLiion temperature [K]: {T[i_last]} | {solution['Temperature [K]'][-1]}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 10
#       7             return element, len(arr) - 1 - idx
#       8     return None, None  # Return None, None if all elements are NaN
# ---> 10 t_last, i_last = last_non_nan(t)
#      12 # Print the final values of time, voltage, and temperature
#      13 print(f"Final PyBaMM | DandeLiion time [s]: {t_last} | {solution['Time [s]'][-1]}")
#
# Cell In[37], line 5, in last_non_nan(arr)
#       1 def last_non_nan(arr):
#       2     """
#       3     A helper function to get the last non-NaN element in an array and its index.
#       4     """
# ----> 5     for idx, element in enumerate(arr[::-1]):
#       6         if not np.isnan(element):
#       7             return element, len(arr) - 1 - idx
#
# IndexError: invalid index to scalar variable.

# %%
# Plot current and voltage vs time.
# Here we access scalar values vs time.
fig, axs = plt.subplots(2, 1, figsize=(10, 8))
axs[0].plot(solution["Time [s]"], solution["Current [A]"], label="Dandeliion")
axs[0].set_xlabel("time [s]")
axs[0].set_title("Current [A]")
axs[0].legend()
axs[0].grid()
axs[1].plot(solution["Time [s]"], solution["Voltage [V]"], label="Dandeliion")
axs[1].set_xlabel("time [s]")
axs[1].set_title("Voltage [V]")
axs[1].legend()
axs[1].grid()
plt.tight_layout()
plt.show()
# Out:
# INFO:dandeliion.client.solution:Fetching 'Current [A]' column from simulator

# %%
# Concentration in the electrolyte vs `x` at the last time step.
# Here we access spatially dependent values vs time.
plt.plot(
    solution["Electrolyte x-coordinate [m]"] * 1e6,
    solution["Electrolyte concentration [mol.m-3]"][-1],
    label="Dandeliion",
)
plt.xlabel(r"x [$\mu$m]")
plt.title("Electrolyte conc. (end of experiment) [mol.m-3]")
plt.legend()
plt.grid()
plt.show()
# Out:
# INFO:dandeliion.client.solution:Fetching 'Electrolyte x-coordinate [m]' column from simulator
# INFO:dandeliion.client.solution:Fetching 'Electrolyte concentration [mol.m-3]' column from simulator

# %%
# A list of output times (optional)
t_eval = np.arange(0, 20, 1)

# If the user needs the solution at the `t_eval` times, the following code can be used (works only correctly on columns with timeline data).
# This is a linear interpolation with constant extrapolation:
print("Time [s]\tVoltage [V]")
for t, voltage in zip(t_eval, solution["Voltage [V]"](t=t_eval)):
    print(f"{t}\t{voltage}")
# Out:
# Time [s]	Voltage [V]
# 0	4.105739335391049
# 1	4.101427662296605
# 2	4.098642664465888
# 3	4.096238093482471
# 4	4.094757223776048
# 5	4.093378987544845
# 6	4.092000751313644
# 7	4.09082470025466
# 8	4.0897352999837695
# 9	4.088645899712879
# 10	4.0875564994419875
# 11	4.086467099171097
# 12	4.085377698900206
# 13	4.084390779669351
# 14	4.083642982865247
# 15	4.082895186061143
# 16	4.082147389257038
# 17	4.081399592452934
# 18	4.080651795648829
# 19	4.079903998844725
